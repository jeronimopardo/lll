# %%
import pandas as pd
from glob import glob
import numpy as np
import seaborn as sns
import re

# %%
files=glob(r'C:\Users\Jeronimo.Pardo\Documents\lll\Noggin Junio\*.csv')


carpeta= (r'C:\Users\Jeronimo.Pardo\Documents\lll\Noggin Junio')

# %%
files
# Out:
# ['C:\\Users\\Jeronimo.Pardo\\Documents\\lll\\Noggin Junio\\Facebook Insights Data Export (Post Level) - Noggin BR - 2019-07-04.csv',
#  'C:\\Users\\Jeronimo.Pardo\\Documents\\lll\\Noggin Junio\\Facebook Insights Data Export (Post Level) - Noggin Latinoamérica - 2019-07-04.csv',
#  'C:\\Users\\Jeronimo.Pardo\\Documents\\lll\\Noggin Junio\\Facebook Insights Data Export - Noggin BR - 2019-07-04.csv',
#  'C:\\Users\\Jeronimo.Pardo\\Documents\\lll\\Noggin Junio\\Facebook Insights Data Export - Noggin Latinoamérica - 2019-07-04.csv',
#  'C:\\Users\\Jeronimo.Pardo\\Documents\\lll\\Noggin Junio\\Reporte-Puppis-mensual-Jun-1-2019-Jun-30-2019.csv']

# %% [markdown]
# ## Facebook - Posts

# %%
df = pd.read_csv(files[0],sep=',', skiprows=[1], index_col=False)

# %%
#df = pd.read_csv(r'%s\Facebook Insights Data Export (Post Level) - Noggin Latinoamérica - 2019-06-26.csv' % carpeta, sep=',', skiprows=[1])

# %%
## Fechas

new = df['Posted'].str.split(" ", n = 1, expand = True) 
df['Fecha'] = new[0]
df['Hora'] = new[1]
df['Dia'] = pd.DatetimeIndex(df['Fecha']).dayofweek
dayDict = {6:'Domingo', 0:'Lunes', 1:'Martes', 2:'Miércoles', 3:'Jueves', 4: 'Viernes', 5:'Sábado' }
df['Dia']=df['Dia'].map(dayDict)

df['Fecha']= pd.to_datetime(df['Fecha']) 
df['Mes'] = df.Fecha.dt.month
df['Hora']= pd.to_datetime(df['Hora']) 
df['Hora'] =  df.Hora.dt.hour


##Campos calculados
df=df.fillna(0)
df['VTR'] = df['Lifetime Organic Video Views'] / df['Lifetime Post Total Reach']

df['E.R.'] =(df['Lifetime Talking About This (Post) by action type - comment'] + df['Lifetime Talking About This (Post) by action type - like'] + df['Lifetime Talking About This (Post) by action type - share']+ df['Lifetime Post Audience Targeting Unique Consumptions by Type - other clicks'] + df['Lifetime Post Audience Targeting Unique Consumptions by Type - link clicks']) / df['Lifetime Post Total Reach']
df=df.replace([np.inf, -np.inf], np.nan)

df=df.fillna(0)

##Comparativo
x=pd.pivot_table(df, index='Mes', values=['Lifetime Post Total Reach', 'Lifetime Post organic reach','Lifetime Organic Video Views', 'Lifetime Talking About This (Post) by action type - comment', 'Lifetime Talking About This (Post) by action type - like','Lifetime Talking About This (Post) by action type - share','Lifetime Post Audience Targeting Unique Consumptions by Type - other clicks','Lifetime Post Audience Targeting Unique Consumptions by Type - link clicks'])
#x=x.sort_values('Mes', ascending=False)

x=x.pct_change()
x=x.fillna(0)

# %%
x.to_csv('Cambios.csv', decimal=".")

# %%
df=df.drop(['Post Message'], axis=1)

# %%
df.VTR=df.VTR.round(4)
df.VTR=df.VTR.astype(float)

df['E.R.']=df['E.R.'].round(4)
#df['E.R.']=df['E.R.'].astype(float)

# %%
df['E.R.'].values[df['E.R.'] > 1] = 0
df['VTR'].values[df['VTR'] > 1] = 0

# %%
df.to_csv('FB_latam.csv', index=False, sep=',', encoding = 'utf-8')

# %%
#with pd.ExcelWriter('output.xls') as writer:  # doctest: +SKIP
#...     df.to_excel(writer, sheet_name='Sheet_name_1')
#...     x.to_excel(writer, sheet_name='Sheet_name_2')

# %% [markdown]
# # Facebook - Followers

# %%
df5 = pd.read_csv(files[2],sep=',', skiprows=[1])

# %%
list(df5)
# Out:
# ['Date',
#  'Lifetime Total Likes',
#  'Daily New Likes',
#  'Daily Unlikes',
#  'Daily Page Engaged Users',
#  'Weekly Page Engaged Users',
#  '28 Days Page Engaged Users',
#  'Daily Total Reach',
#  'Weekly Total Reach',
#  '28 Days Total Reach',
#  'Daily Organic Reach',
#  'Weekly Organic Reach',
#  '28 Days Organic Reach',
#  'Daily Paid Reach',
#  'Weekly Paid Reach',
#  '28 Days Paid Reach',
#  'Daily Viral Reach',
#  'Weekly Viral Reach',
#  '28 Days Viral Reach',
#  'Daily Total Impressions',
#  'Weekly Total Impressions',
#  '28 Days Total Impressions',
#  'Daily Organic impressions',
#  'Weekly Organic impressions',
#  '28 Days Organic impressions',
#  'Daily Paid Impressions',
#  'Weekly Paid Impressions',
#  '28 Days Paid Impressions',
#  'Daily Viral impressions',
#  'Weekly Viral impressions',
#  '28 Days Viral impressions',
#  'Daily Logged-in Page Views',
#  'Weekly Logged-in Page Views',
#  'Daily Logged-in Page Views.1',
#  'Weekly Logged-in Page Views.1',
#  'Daily Reach Of Page Posts',
#  'Weekly Reach Of Page Posts',
#  '28 Days Reach Of Page Posts',
#  'Daily Organic Reach of Page posts',
#  'Weekly Organic Reach of Page posts',
#  '28 Days Organic Reach of Page posts',
#  'Daily Paid Reach of Page posts',
#  'Weekly Paid Reach of Page posts',
#  '28 Days Paid Reach of Page posts',
#  'Daily Viral Reach Of Page Posts',
#  'Weekly Viral Reach Of Page Posts',
#  '28 Days Viral Reach Of Page Posts',
#  'Daily Total Impressions of your posts',
#  'Weekly Total Impressions of your posts',
#  '28 Days Total Impressions of your posts',
#  'Daily Organic impressions of your posts',
#  'Weekly Organic impressions of your posts',
#  '28 Days Organic impressions of your posts',
#  'Daily Paid impressions of your posts',
#  'Weekly Paid impressions of your posts',
#  '28 Days Paid impressions of your posts',
#  'Daily Viral Impressions Of Your Posts',
#  'Weekly Viral Impressions Of Your Posts',
#  '28 Days Viral Impressions Of Your Posts',
#  'Daily Total Consumers',
#  'Weekly Total Consumers',
#  '28 Days Total Consumers',
#  'Daily Page Consumptions',
#  'Weekly Page Consumptions',
#  '28 Days Page Consumptions',
#  'Daily Negative Feedback',
#  'Weekly Negative Feedback',
#  '28 Days Negative Feedback',
#  'Daily Negative Feedback From Users',
#  'Weekly Negative Feedback From Users',
#  '28 Days Negative Feedback From Users',
#  'Daily Total Check-Ins',
#  'Weekly Total Check-Ins',
#  '28 Days Total Check-Ins',
#  'Daily Total Check-Ins.1',
#  'Weekly Total Check-Ins.1',
#  '28 Days Total Check-Ins.1',
#  'Daily Total Check-Ins Using Mobile Devices',
#  'Weekly Total Check-Ins Using Mobile Devices',
#  '28 Days Total Check-Ins Using Mobile Devices',
#  'Daily Total Check-Ins Using Mobile Devices.1',
#  'Weekly Total Check-Ins Using Mobile Devices.1',
#  '28 Days Total Check-Ins Using Mobile Devices.1',
#  'Daily Total Organic Views',
#  'Weekly Total Organic Views',
#  '28 Days Total Organic Views',
#  'Daily Total Promoted Views',
#  'Weekly Total Promoted Views',
#  '28 Days Total Promoted Views',
#  'Daily Total Organic 30-Second Views',
#  'Weekly Total Organic 30-Second Views',
#  '28 Days Total Organic 30-Second Views',
#  'Daily Paid 30-Second Views',
#  'Weekly Paid 30-Second Views',
#  '28 Days Paid 30-Second Views',
#  'Daily Total Video Views',
#  'Weekly Total Video Views',
#  '28 Days Total Video Views',
#  'Daily Total Auto-Played Views',
#  'Weekly Total Auto-Played Views',
#  '28 Days Total Auto-Played Views',
#  'Daily Total Clicked Views',
#  'Weekly Total Clicked Views',
#  '28 Days Total Clicked Views',
#  'Daily Video Repeats',
#  'Weekly Video Repeats',
#  '28 Days Video Repeats',
#  'Daily Total Unique Video Views',
#  'Weekly Total Unique Video Views',
#  '28 Days Total Unique Video Views',
#  'Daily Total 30-Second Views',
#  'Weekly Total 30-Second Views',
#  '28 Days Total 30-Second Views',
#  'Daily Auto-Played 30-Second Views',
#  'Weekly Auto-Played 30-Second Views',
#  '28 Days Auto-Played 30-Second Views',
#  'Daily Total Clicked 30-Second Views',
#  'Weekly Total Clicked 30-Second Views',
#  '28 Days Total Clicked 30-Second Views',
#  'Daily Total 30-Second Repeats',
#  'Weekly Total 30-Second Repeats',
#  '28 Days Total 30-Second Repeats',
#  'Daily Total Unique 30-Second Views',
#  'Weekly Total Unique 30-Second Views',
#  '28 Days Total Unique 30-Second Views',
#  'Daily Total: total action count per Page',
#  'Weekly Total: total action count per Page',
#  'Daily Total get direction click count per Page',
#  'Weekly Total get direction click count per Page',
#  'Daily Total get direction click count per Page.1',
#  'Weekly Total get direction click count per Page.1',
#  'Daily Total phone calls click count per Page',
#  'Weekly Total phone calls click count per Page',
#  'Daily Total phone calls click count per Page.1',
#  'Weekly Total phone calls click count per Page.1',
#  'Daily Total website click count per Page',
#  'Weekly Total website click count per Page',
#  'Daily Total website click count per Page.1',
#  'Weekly Total website click count per Page.1',
#  'Daily Like Sources - feed_chaining',
#  'Daily Like Sources - feed_pyml',
#  'Daily Like Sources - feed_story',
#  'Daily Like Sources - hovercard',
#  'Daily Like Sources - mobile_app',
#  'Daily Like Sources - page_profile',
#  'Daily Like Sources - page_timeline',
#  'Daily Like Sources - pagelike_adder_for_reactivated_users',
#  'Daily Like Sources - search',
#  'Daily Like Sources - timeline_like_chaining',
#  'Daily Like Sources - unknown',
#  'Daily Total Frequency Distribution - 1',
#  'Daily Total Frequency Distribution - 2',
#  'Daily Total Frequency Distribution - 3',
#  'Daily Total Frequency Distribution - 4',
#  'Daily Total Frequency Distribution - 5',
#  'Daily Total Frequency Distribution - 6-10',
#  'Daily Total Frequency Distribution - 11-20',
#  'Daily Total Frequency Distribution - 21+',
#  'Weekly Total Frequency Distribution - 1',
#  'Weekly Total Frequency Distribution - 2',
#  'Weekly Total Frequency Distribution - 3',
#  'Weekly Total Frequency Distribution - 4',
#  'Weekly Total Frequency Distribution - 5',
#  'Weekly Total Frequency Distribution - 6-10',
#  'Weekly Total Frequency Distribution - 11-20',
#  'Weekly Total Frequency Distribution - 21+',
#  '28 Days Total Frequency Distribution - 1',
#  '28 Days Total Frequency Distribution - 2',
#  '28 Days Total Frequency Distribution - 3',
#  '28 Days Total Frequency Distribution - 4',
#  '28 Days Total Frequency Distribution - 5',
#  '28 Days Total Frequency Distribution - 6-10',
#  '28 Days Total Frequency Distribution - 11-20',
#  '28 Days Total Frequency Distribution - 21+',
#  'Daily Page Posts Frequency Distribution - 1',
#  'Daily Page Posts Frequency Distribution - 2',
#  'Daily Page Posts Frequency Distribution - 3',
#  'Daily Page Posts Frequency Distribution - 4',
#  'Daily Page Posts Frequency Distribution - 5',
#  'Daily Page Posts Frequency Distribution - 6-10',
#  'Daily Page Posts Frequency Distribution - 11-20',
#  'Daily Page Posts Frequency Distribution - 21+',
#  'Weekly Page Posts Frequency Distribution - 1',
#  'Weekly Page Posts Frequency Distribution - 2',
#  'Weekly Page Posts Frequency Distribution - 3',
#  'Weekly Page Posts Frequency Distribution - 4',
#  'Weekly Page Posts Frequency Distribution - 5',
#  'Weekly Page Posts Frequency Distribution - 6-10',
#  'Weekly Page Posts Frequency Distribution - 11-20',
#  'Weekly Page Posts Frequency Distribution - 21+',
#  '28 Days Page Posts Frequency Distribution - 1',
#  '28 Days Page Posts Frequency Distribution - 2',
#  '28 Days Page Posts Frequency Distribution - 3',
#  '28 Days Page Posts Frequency Distribution - 4',
#  '28 Days Page Posts Frequency Distribution - 5',
#  '28 Days Page Posts Frequency Distribution - 6-10',
#  '28 Days Page Posts Frequency Distribution - 11-20',
#  '28 Days Page Posts Frequency Distribution - 21+',
#  'Daily Talking About This By Story Type - checkin',
#  'Daily Talking About This By Story Type - coupon',
#  'Daily Talking About This By Story Type - event',
#  'Daily Talking About This By Story Type - fan',
#  'Daily Talking About This By Story Type - mention',
#  'Daily Talking About This By Story Type - other',
#  'Daily Talking About This By Story Type - page post',
#  'Daily Talking About This By Story Type - question',
#  'Daily Talking About This By Story Type - user post',
#  'Weekly Talking About This By Story Type - checkin',
#  'Weekly Talking About This By Story Type - coupon',
#  'Weekly Talking About This By Story Type - event',
#  'Weekly Talking About This By Story Type - fan',
#  'Weekly Talking About This By Story Type - mention',
#  'Weekly Talking About This By Story Type - other',
#  'Weekly Talking About This By Story Type - page post',
#  'Weekly Talking About This By Story Type - question',
#  'Weekly Talking About This By Story Type - user post',
#  '28 Days Talking About This By Story Type - checkin',
#  '28 Days Talking About This By Story Type - coupon',
#  '28 Days Talking About This By Story Type - event',
#  '28 Days Talking About This By Story Type - fan',
#  '28 Days Talking About This By Story Type - mention',
#  '28 Days Talking About This By Story Type - other',
#  '28 Days Talking About This By Story Type - page post',
#  '28 Days Talking About This By Story Type - question',
#  '28 Days Talking About This By Story Type - user post',
#  'Daily Page Stories By Story Type - checkin',
#  'Daily Page Stories By Story Type - coupon',
#  'Daily Page Stories By Story Type - event',
#  'Daily Page Stories By Story Type - fan',
#  'Daily Page Stories By Story Type - mention',
#  'Daily Page Stories By Story Type - other',
#  'Daily Page Stories By Story Type - page post',
#  'Daily Page Stories By Story Type - question',
#  'Daily Page Stories By Story Type - user post',
#  'Weekly Page Stories By Story Type - checkin',
#  'Weekly Page Stories By Story Type - coupon',
#  'Weekly Page Stories By Story Type - event',
#  'Weekly Page Stories By Story Type - fan',
#  'Weekly Page Stories By Story Type - mention',
#  'Weekly Page Stories By Story Type - other',
#  'Weekly Page Stories By Story Type - page post',
#  'Weekly Page Stories By Story Type - question',
#  'Weekly Page Stories By Story Type - user post',
#  '28 Days Page Stories By Story Type - checkin',
#  '28 Days Page Stories By Story Type - coupon',
#  '28 Days Page Stories By Story Type - event',
#  '28 Days Page Stories By Story Type - fan',
#  '28 Days Page Stories By Story Type - mention',
#  '28 Days Page Stories By Story Type - other',
#  '28 Days Page Stories By Story Type - page post',
#  '28 Days Page Stories By Story Type - question',
#  '28 Days Page Stories By Story Type - user post',
#  'Daily Page Consumptions By Type - button clicks',
#  'Daily Page Consumptions By Type - link clicks',
#  'Daily Page Consumptions By Type - other clicks',
#  'Daily Page Consumptions By Type - photo view',
#  'Daily Page Consumptions By Type - video play',
#  'Weekly Page Consumptions By Type - button clicks',
#  'Weekly Page Consumptions By Type - link clicks',
#  'Weekly Page Consumptions By Type - other clicks',
#  'Weekly Page Consumptions By Type - photo view',
#  'Weekly Page Consumptions By Type - video play',
#  '28 Days Page Consumptions By Type - button clicks',
#  '28 Days Page Consumptions By Type - link clicks',
#  '28 Days Page Consumptions By Type - other clicks',
#  '28 Days Page Consumptions By Type - photo view',
#  '28 Days Page Consumptions By Type - video play',
#  'Lifetime Likes by Gender and Age - F.13-17',
#  'Lifetime Likes by Gender and Age - F.18-24',
#  'Lifetime Likes by Gender and Age - F.25-34',
#  'Lifetime Likes by Gender and Age - F.35-44',
#  'Lifetime Likes by Gender and Age - F.45-54',
#  'Lifetime Likes by Gender and Age - F.55-64',
#  'Lifetime Likes by Gender and Age - F.65+',
#  'Lifetime Likes by Gender and Age - M.13-17',
#  'Lifetime Likes by Gender and Age - M.18-24',
#  'Lifetime Likes by Gender and Age - M.25-34',
#  'Lifetime Likes by Gender and Age - M.35-44',
#  'Lifetime Likes by Gender and Age - M.45-54',
#  'Lifetime Likes by Gender and Age - M.55-64',
#  'Lifetime Likes by Gender and Age - M.65+',
#  'Lifetime Likes by Gender and Age - U.18-24',
#  'Lifetime Likes by Gender and Age - U.25-34',
#  'Lifetime Likes by Gender and Age - U.35-44',
#  'Lifetime Likes by Gender and Age - U.45-54',
#  'Lifetime Likes by Gender and Age - U.65+',
#  'Lifetime Likes by Country - AR',
#  'Lifetime Likes by Country - AU',
#  'Lifetime Likes by Country - BE',
#  'Lifetime Likes by Country - BO',
#  'Lifetime Likes by Country - BR',
#  'Lifetime Likes by Country - CA',
#  'Lifetime Likes by Country - CL',
#  'Lifetime Likes by Country - CN',
#  'Lifetime Likes by Country - CO',
#  'Lifetime Likes by Country - CR',
#  'Lifetime Likes by Country - CU',
#  'Lifetime Likes by Country - DE',
#  'Lifetime Likes by Country - DO',
#  'Lifetime Likes by Country - DZ',
#  'Lifetime Likes by Country - EC',
#  'Lifetime Likes by Country - EG',
#  'Lifetime Likes by Country - ES',
#  'Lifetime Likes by Country - FR',
#  'Lifetime Likes by Country - GB',
#  'Lifetime Likes by Country - GT',
#  'Lifetime Likes by Country - HN',
#  'Lifetime Likes by Country - HR',
#  'Lifetime Likes by Country - ID',
#  'Lifetime Likes by Country - IL',
#  'Lifetime Likes by Country - IN',
#  'Lifetime Likes by Country - IQ',
#  'Lifetime Likes by Country - IT',
#  'Lifetime Likes by Country - JP',
#  'Lifetime Likes by Country - LB',
#  'Lifetime Likes by Country - MX',
#  'Lifetime Likes by Country - NI',
#  'Lifetime Likes by Country - NL',
#  'Lifetime Likes by Country - PA',
#  'Lifetime Likes by Country - PE',
#  'Lifetime Likes by Country - PH',
#  'Lifetime Likes by Country - PK',
#  'Lifetime Likes by Country - PR',
#  'Lifetime Likes by Country - PS',
#  'Lifetime Likes by Country - PY',
#  'Lifetime Likes by Country - SA',
#  'Lifetime Likes by Country - SE',
#  'Lifetime Likes by Country - SV',
#  'Lifetime Likes by Country - SY',
#  'Lifetime Likes by Country - TH',
#  'Lifetime Likes by Country - TN',
#  'Lifetime Likes by Country - TR',
#  'Lifetime Likes by Country - TT',
#  'Lifetime Likes by Country - US',
#  'Lifetime Likes by Country - UY',
#  'Lifetime Likes by Country - VE',
#  'Lifetime Likes by Country - VN',
#  'Lifetime Likes by City - Acapulco, Mexico',
#  'Lifetime Likes by City - Aguascalientes, Mexico',
#  'Lifetime Likes by City - Asunción, Paraguay',
#  'Lifetime Likes by City - Barranquilla, Colombia',
#  'Lifetime Likes by City - Bogotá, Colombia',
#  'Lifetime Likes by City - Buenos Aires, Argentina',
#  'Lifetime Likes by City - Cancún, Mexico',
#  'Lifetime Likes by City - Cartagena, Colombia',
#  'Lifetime Likes by City - Chihuahua, Mexico',
#  'Lifetime Likes by City - Ciudad Juárez, Mexico',
#  'Lifetime Likes by City - Coatzacoalcos, Mexico',
#  'Lifetime Likes by City - Cuernavaca, Mexico',
#  'Lifetime Likes by City - Culiacán, Mexico',
#  'Lifetime Likes by City - Ecatepec de Morelos, Mexico',
#  'Lifetime Likes by City - Estado de México, Mexico',
#  'Lifetime Likes by City - Guadalajara, Mexico',
#  'Lifetime Likes by City - Guayaquil, Ecuador',
#  'Lifetime Likes by City - Hermosillo, Mexico',
#  'Lifetime Likes by City - La Paz, Bolivia',
#  'Lifetime Likes by City - León, Mexico',
#  'Lifetime Likes by City - Lima, Peru',
#  'Lifetime Likes by City - Mérida, Mexico',
#  'Lifetime Likes by City - Matamoros, Mexico',
#  'Lifetime Likes by City - Medellín, Colombia',
#  'Lifetime Likes by City - Mexicali, Mexico',
#  'Lifetime Likes by City - Mexico City, Mexico',
#  'Lifetime Likes by City - Monterrey, Mexico',
#  'Lifetime Likes by City - Morelia, Mexico',
#  'Lifetime Likes by City - Oaxaca de Juárez, Mexico',
#  'Lifetime Likes by City - Puebla, Mexico',
#  'Lifetime Likes by City - Querétaro, Mexico',
#  'Lifetime Likes by City - Quito, Ecuador',
#  'Lifetime Likes by City - Reynosa, Mexico',
#  'Lifetime Likes by City - Saltillo, Mexico',
#  'Lifetime Likes by City - San Luis Potosí, Mexico',
#  'Lifetime Likes by City - Santa Cruz de la Sierra, Bolivia',
#  'Lifetime Likes by City - Santiago, Chile',
#  'Lifetime Likes by City - Santiago de Cali, Colombia',
#  'Lifetime Likes by City - Tampico, Mexico',
#  'Lifetime Likes by City - Tijuana, Mexico',
#  'Lifetime Likes by City - Toluca, Mexico',
#  'Lifetime Likes by City - Torreón, Mexico',
#  'Lifetime Likes by City - Tuxtla Gutiérrez, Mexico',
#  'Lifetime Likes by City - Veracruz, Mexico',
#  'Lifetime Likes by City - Villahermosa, Mexico',
#  'Lifetime Likes by Language - af_ZA',
#  'Lifetime Likes by Language - ar_AR',
#  'Lifetime Likes by Language - az_AZ',
#  'Lifetime Likes by Language - bg_BG',
#  'Lifetime Likes by Language - de_DE',
#  'Lifetime Likes by Language - en_GB',
#  'Lifetime Likes by Language - en_US',
#  'Lifetime Likes by Language - es_ES',
#  'Lifetime Likes by Language - es_LA',
#  'Lifetime Likes by Language - es_MX',
#  'Lifetime Likes by Language - fr_CA',
#  'Lifetime Likes by Language - fr_FR',
#  'Lifetime Likes by Language - gu_IN',
#  'Lifetime Likes by Language - he_IL',
#  'Lifetime Likes by Language - hi_IN',
#  'Lifetime Likes by Language - id_ID',
#  'Lifetime Likes by Language - it_IT',
#  'Lifetime Likes by Language - ja_JP',
#  'Lifetime Likes by Language - ko_KR',
#  'Lifetime Likes by Language - ms_MY',
#  'Lifetime Likes by Language - pl_PL',
#  'Lifetime Likes by Language - ps_AF',
#  'Lifetime Likes by Language - pt_BR',
#  'Lifetime Likes by Language - pt_PT',
#  'Lifetime Likes by Language - sv_SE',
#  'Lifetime Likes by Language - th_TH',
#  'Lifetime Likes by Language - tr_TR',
#  'Lifetime Likes by Language - uk_UA',
#  'Lifetime Likes by Language - vi_VN',
#  'Lifetime Likes by Language - zh_CN',
#  'Lifetime Likes by Language - zh_TW',
#  'Weekly Reach Demographics - F.13-17',
#  'Weekly Reach Demographics - F.18-24',
#  'Weekly Reach Demographics - F.25-34',
#  'Weekly Reach Demographics - F.35-44',
#  'Weekly Reach Demographics - F.45-54',
#  'Weekly Reach Demographics - F.55-64',
#  'Weekly Reach Demographics - F.65+',
#  'Weekly Reach Demographics - M.13-17',
#  'Weekly Reach Demographics - M.18-24',
#  'Weekly Reach Demographics - M.25-34',
#  'Weekly Reach Demographics - M.35-44',
#  'Weekly Reach Demographics - M.45-54',
#  'Weekly Reach Demographics - M.55-64',
#  'Weekly Reach Demographics - M.65+',
#  'Weekly Reach Demographics - U.18-24',
#  'Weekly Reach Demographics - U.25-34',
#  'Weekly Reach Demographics - U.35-44',
#  'Weekly Reach Demographics - U.45-54',
#  'Weekly Reach Demographics - U.65+',
#  'Weekly Reach by Country - AE',
#  'Weekly Reach by Country - AR',
#  'Weekly Reach by Country - AU',
#  'Weekly Reach by Country - AW',
#  'Weekly Reach by Country - BO',
#  'Weekly Reach by Country - BR',
#  'Weekly Reach by Country - BZ',
#  'Weekly Reach by Country - CA',
#  'Weekly Reach by Country - CH',
#  'Weekly Reach by Country - CL',
#  'Weekly Reach by Country - CN',
#  'Weekly Reach by Country - CO',
#  'Weekly Reach by Country - CR',
#  'Weekly Reach by Country - CU',
#  'Weekly Reach by Country - CW',
#  'Weekly Reach by Country - DE',
#  'Weekly Reach by Country - DK',
#  'Weekly Reach by Country - DO',
#  'Weekly Reach by Country - EC',
#  'Weekly Reach by Country - ES',
#  'Weekly Reach by Country - FR',
#  'Weekly Reach by Country - GB',
#  'Weekly Reach by Country - GQ',
#  'Weekly Reach by Country - GT',
#  'Weekly Reach by Country - HN',
#  'Weekly Reach by Country - HT',
#  'Weekly Reach by Country - ID',
#  'Weekly Reach by Country - IE',
#  'Weekly Reach by Country - IL',
#  'Weekly Reach by Country - IN',
#  'Weekly Reach by Country - IR',
#  'Weekly Reach by Country - IT',
#  'Weekly Reach by Country - MA',
#  'Weekly Reach by Country - ME',
#  'Weekly Reach by Country - MG',
#  'Weekly Reach by Country - MM',
#  'Weekly Reach by Country - MX',
#  'Weekly Reach by Country - MY',
#  'Weekly Reach by Country - NG',
#  'Weekly Reach by Country - NI',
#  'Weekly Reach by Country - NL',
#  'Weekly Reach by Country - NO',
#  'Weekly Reach by Country - NZ',
#  'Weekly Reach by Country - PA',
#  'Weekly Reach by Country - PE',
#  'Weekly Reach by Country - PH',
#  'Weekly Reach by Country - PK',
#  'Weekly Reach by Country - PR',
#  'Weekly Reach by Country - PT',
#  'Weekly Reach by Country - PY',
#  'Weekly Reach by Country - RU',
#  'Weekly Reach by Country - SA',
#  'Weekly Reach by Country - SE',
#  'Weekly Reach by Country - SI',
#  'Weekly Reach by Country - SV',
#  'Weekly Reach by Country - TR',
#  'Weekly Reach by Country - TT',
#  'Weekly Reach by Country - TZ',
#  'Weekly Reach by Country - US',
#  'Weekly Reach by Country - UY',
#  'Weekly Reach by Country - VE',
#  'Weekly Reach by Country - ZA',
#  'Weekly Reach by City - Acapulco, Mexico',
#  'Weekly Reach by City - Acolman, Mexico',
#  'Weekly Reach by City - Acuña, Mexico',
#  'Weekly Reach by City - Aguascalientes, Mexico',
#  'Weekly Reach by City - Apodaca, Mexico',
#  'Weekly Reach by City - Arequipa, Peru',
#  'Weekly Reach by City - Barranquilla, Colombia',
#  'Weekly Reach by City - Bogotá, Colombia',
#  'Weekly Reach by City - Buenos Aires, Argentina',
#  'Weekly Reach by City - Cárdenas, Mexico',
#  'Weekly Reach by City - Cadereyta Jiménez, Mexico',
#  'Weekly Reach by City - Cancún, Mexico',
#  'Weekly Reach by City - Celaya, Mexico',
#  'Weekly Reach by City - Chalco, Mexico',
#  'Weekly Reach by City - Chetumal, Mexico',
#  'Weekly Reach by City - Chiclayo, Peru',
#  'Weekly Reach by City - Chicoloapan, Mexico',
#  'Weekly Reach by City - Chihuahua, Mexico',
#  'Weekly Reach by City - Chimalhuacán, Mexico',
#  'Weekly Reach by City - Ciénega de Flores, Mexico',
#  'Weekly Reach by City - Ciudad Juárez, Mexico',
#  'Weekly Reach by City - Ciudad Obregón, Mexico',
#  'Weekly Reach by City - Ciudad Victoria, Mexico',
#  'Weekly Reach by City - Coacalco, Mexico',
#  'Weekly Reach by City - Coatzacoalcos, Mexico',
#  'Weekly Reach by City - Coscomatepec, Mexico',
#  'Weekly Reach by City - Coyotepec, Mexico',
#  'Weekly Reach by City - Cuautitlán, Mexico',
#  'Weekly Reach by City - Cuautitlán Izcalli, Mexico',
#  'Weekly Reach by City - Culiacán, Mexico',
#  'Weekly Reach by City - Cusco, Peru',
#  'Weekly Reach by City - Delicias, Mexico',
#  'Weekly Reach by City - Durango, Mexico',
#  'Weekly Reach by City - Ecatepec de Morelos, Mexico',
#  'Weekly Reach by City - Ensenada, Mexico',
#  'Weekly Reach by City - Estado de México, Mexico',
#  'Weekly Reach by City - Gómez Palacio, Mexico',
#  'Weekly Reach by City - Garcia, Mexico',
#  'Weekly Reach by City - General Escobedo, Mexico',
#  'Weekly Reach by City - General Zuazua, Mexico',
#  'Weekly Reach by City - Guadalajara, Mexico',
#  'Weekly Reach by City - Guadalupe, Mexico',
#  'Weekly Reach by City - Guasave, Mexico',
#  'Weekly Reach by City - Guatemala City, Guatemala',
#  'Weekly Reach by City - Guayaquil, Ecuador',
#  'Weekly Reach by City - Hermosillo, Mexico',
#  'Weekly Reach by City - Huancayo, Peru',
#  'Weekly Reach by City - Huixtla, Mexico',
#  'Weekly Reach by City - Ica, Peru',
#  'Weekly Reach by City - Irapuato, Mexico',
#  'Weekly Reach by City - Ixtapaluca, Mexico',
#  'Weekly Reach by City - Juárez, Mexico',
#  'Weekly Reach by City - Juliaca, Peru',
#  'Weekly Reach by City - Lázaro Cárdenas, Mexico',
#  'Weekly Reach by City - López Mateos, Mexico',
#  'Weekly Reach by City - León, Mexico',
#  'Weekly Reach by City - Lerma, Mexico',
#  'Weekly Reach by City - Lima, Peru',
#  'Weekly Reach by City - Los Mochis, Mexico',
#  'Weekly Reach by City - Los Reyes Acaquilpan, Mexico',
#  'Weekly Reach by City - Mérida, Mexico',
#  'Weekly Reach by City - Managua, Nicaragua',
#  'Weekly Reach by City - Manzanillo, Mexico',
#  'Weekly Reach by City - Matamoros, Mexico',
#  'Weekly Reach by City - Mazatlán, Mexico',
#  'Weekly Reach by City - Medellín, Colombia',
#  'Weekly Reach by City - Melchor Ocampo, Mexico',
#  'Weekly Reach by City - Mexicali, Mexico',
#  'Weekly Reach by City - Mexico City, Mexico',
#  'Weekly Reach by City - Monclova, Mexico',
#  'Weekly Reach by City - Monterrey, Mexico',
#  'Weekly Reach by City - Morelia, Mexico',
#  'Weekly Reach by City - Naucalpan, Mexico',
#  'Weekly Reach by City - Nezahualcóyotl, Mexico',
#  'Weekly Reach by City - Nuevo Laredo, Mexico',
#  'Weekly Reach by City - Oaxaca de Juárez, Mexico',
#  'Weekly Reach by City - Ocoyoacac, Mexico',
#  'Weekly Reach by City - Panama City, Panama',
#  'Weekly Reach by City - Playa del Carmen, Mexico',
#  'Weekly Reach by City - Pucallpa, Peru',
#  'Weekly Reach by City - Puebla, Mexico',
#  'Weekly Reach by City - Puerto Vallarta, Mexico',
#  'Weekly Reach by City - Puerto Viejo, Costa Rica',
#  'Weekly Reach by City - Querétaro, Mexico',
#  'Weekly Reach by City - Quito, Ecuador',
#  'Weekly Reach by City - Reynosa, Mexico',
#  'Weekly Reach by City - Saltillo, Mexico',
#  'Weekly Reach by City - San Luis Potosí, Mexico',
#  'Weekly Reach by City - San Mateo Cuautepec, Mexico',
#  'Weekly Reach by City - San Nicolás de los Garza, Mexico',
#  'Weekly Reach by City - San Pablo de las Salinas, Mexico',
#  'Weekly Reach by City - San Pedro Sula, Honduras',
#  'Weekly Reach by City - San Salvador, El Salvador',
#  'Weekly Reach by City - Santa Catarina, Mexico',
#  'Weekly Reach by City - Santa Cruz de la Sierra, Bolivia',
#  'Weekly Reach by City - Santiago, Chile',
#  'Weekly Reach by City - Saucillo, Mexico',
#  'Weekly Reach by City - Tampico, Mexico',
#  'Weekly Reach by City - Tapachula, Mexico',
#  'Weekly Reach by City - Tecamac, Mexico',
#  'Weekly Reach by City - Tegucigalpa, Honduras',
#  'Weekly Reach by City - Teoloyucan, Mexico',
#  'Weekly Reach by City - Teotihuacán, Mexico',
#  'Weekly Reach by City - Tepic, Mexico',
#  'Weekly Reach by City - Tepotzotlán, Mexico',
#  'Weekly Reach by City - Texcoco de Mora, Mexico',
#  'Weekly Reach by City - Tianguistenco, Mexico',
#  'Weekly Reach by City - Tijuana, Mexico',
#  'Weekly Reach by City - Tlajomulco de Zúñiga, Mexico',
#  'Weekly Reach by City - Tlaquepaque, Mexico',
#  'Weekly Reach by City - Toluca, Mexico',
#  'Weekly Reach by City - Tonalá, Mexico',
#  'Weekly Reach by City - Torreón, Mexico',
#  'Weekly Reach by City - Trujillo, Peru',
#  'Weekly Reach by City - Tultepec, Mexico',
#  'Weekly Reach by City - Tuxtla Gutiérrez, Mexico',
#  'Weekly Reach by City - Uruapan, Mexico',
#  'Weekly Reach by City - Valle de Bravo, Mexico',
#  'Weekly Reach by City - Veracruz, Mexico',
#  'Weekly Reach by City - Villa Nicolás Romero, Mexico',
#  'Weekly Reach by City - Villahermosa, Mexico',
#  'Weekly Reach by City - Xalapa, Mexico',
#  'Weekly Reach by City - Xico, Mexico',
#  'Weekly Reach by City - Zapopan, Mexico',
#  'Weekly Reach by City - Zitácuaro, Mexico',
#  'Weekly Reach by City - Zumpango, Mexico',
#  'Weekly Reach by Language - af_ZA',
#  'Weekly Reach by Language - am_ET',
#  'Weekly Reach by Language - ar_AR',
#  'Weekly Reach by Language - as_IN',
#  'Weekly Reach by Language - az_AZ',
#  'Weekly Reach by Language - bs_BA',
#  'Weekly Reach by Language - ca_ES',
#  'Weekly Reach by Language - cs_CZ',
#  'Weekly Reach by Language - cx_PH',
#  'Weekly Reach by Language - da_DK',
#  'Weekly Reach by Language - de_DE',
#  'Weekly Reach by Language - en_GB',
#  'Weekly Reach by Language - en_PI',
#  'Weekly Reach by Language - en_UD',
#  'Weekly Reach by Language - en_US',
#  'Weekly Reach by Language - es_CL',
#  'Weekly Reach by Language - es_CO',
#  'Weekly Reach by Language - es_ES',
#  'Weekly Reach by Language - es_LA',
#  'Weekly Reach by Language - es_MX',
#  'Weekly Reach by Language - et_EE',
#  'Weekly Reach by Language - fa_IR',
#  'Weekly Reach by Language - fb_LT',
#  'Weekly Reach by Language - fi_FI',
#  'Weekly Reach by Language - fr_CA',
#  'Weekly Reach by Language - fr_FR',
#  'Weekly Reach by Language - ga_IE',
#  'Weekly Reach by Language - gu_IN',
#  'Weekly Reach by Language - ha_NG',
#  'Weekly Reach by Language - he_IL',
#  'Weekly Reach by Language - hi_IN',
#  'Weekly Reach by Language - hr_HR',
#  'Weekly Reach by Language - hu_HU',
#  'Weekly Reach by Language - id_ID',
#  'Weekly Reach by Language - it_IT',
#  'Weekly Reach by Language - ja_JP',
#  'Weekly Reach by Language - ja_KS',
#  'Weekly Reach by Language - jv_ID',
#  'Weekly Reach by Language - ka_GE',
#  'Weekly Reach by Language - km_KH',
#  'Weekly Reach by Language - ko_KR',
#  'Weekly Reach by Language - la_VA',
#  'Weekly Reach by Language - lv_LV',
#  'Weekly Reach by Language - ms_MY',
#  'Weekly Reach by Language - my_MM',
#  'Weekly Reach by Language - nb_NO',
#  'Weekly Reach by Language - ne_NP',
#  'Weekly Reach by Language - nl_NL',
#  'Weekly Reach by Language - pl_PL',
#  'Weekly Reach by Language - pt_BR',
#  'Weekly Reach by Language - pt_PT',
#  'Weekly Reach by Language - ro_RO',
#  'Weekly Reach by Language - ru_RU',
#  'Weekly Reach by Language - sk_SK',
#  'Weekly Reach by Language - so_SO',
#  'Weekly Reach by Language - sq_AL',
#  'Weekly Reach by Language - sv_SE',
#  'Weekly Reach by Language - sw_KE',
#  'Weekly Reach by Language - tg_TJ',
#  'Weekly Reach by Language - th_TH',
#  'Weekly Reach by Language - tl_PH',
#  'Weekly Reach by Language - tr_TR',
#  'Weekly Reach by Language - tz_MA',
#  'Weekly Reach by Language - vi_VN',
#  'Weekly Reach by Language - zh_CN',
#  'Weekly Reach by Language - zh_TW',
#  'Daily Demographics: People Talking About This - F.13-17',
#  'Daily Demographics: People Talking About This - F.18-24',
#  'Daily Demographics: People Talking About This - F.25-34',
#  'Daily Demographics: People Talking About This - F.35-44',
#  'Daily Demographics: People Talking About This - F.45-54',
#  'Daily Demographics: People Talking About This - F.55-64',
#  'Daily Demographics: People Talking About This - F.65+',
#  'Daily Demographics: People Talking About This - M.13-17',
#  'Daily Demographics: People Talking About This - M.18-24',
#  'Daily Demographics: People Talking About This - M.25-34',
#  'Daily Demographics: People Talking About This - M.35-44',
#  'Daily Demographics: People Talking About This - M.45-54',
#  'Daily Demographics: People Talking About This - M.55-64',
#  'Daily Demographics: People Talking About This - M.65+',
#  'Daily Demographics: People Talking About This - U.25-34',
#  'Daily Demographics: People Talking About This - U.35-44',
#  'Daily Demographics: People Talking About This - U.45-54',
#  'Weekly Demographics: People Talking About This - F.13-17',
#  'Weekly Demographics: People Talking About This - F.18-24',
#  'Weekly Demographics: People Talking About This - F.25-34',
#  'Weekly Demographics: People Talking About This - F.35-44',
#  'Weekly Demographics: People Talking About This - F.45-54',
#  'Weekly Demographics: People Talking About This - F.55-64',
#  'Weekly Demographics: People Talking About This - F.65+',
#  'Weekly Demographics: People Talking About This - M.13-17',
#  'Weekly Demographics: People Talking About This - M.18-24',
#  'Weekly Demographics: People Talking About This - M.25-34',
#  'Weekly Demographics: People Talking About This - M.35-44',
#  'Weekly Demographics: People Talking About This - M.45-54',
#  'Weekly Demographics: People Talking About This - M.55-64',
#  'Weekly Demographics: People Talking About This - M.65+',
#  'Weekly Demographics: People Talking About This - U.25-34',
#  'Weekly Demographics: People Talking About This - U.35-44',
#  'Weekly Demographics: People Talking About This - U.45-54',
#  '28 Days Demographics: People Talking About This - F.13-17',
#  '28 Days Demographics: People Talking About This - F.18-24',
#  '28 Days Demographics: People Talking About This - F.25-34',
#  '28 Days Demographics: People Talking About This - F.35-44',
#  '28 Days Demographics: People Talking About This - F.45-54',
#  '28 Days Demographics: People Talking About This - F.55-64',
#  '28 Days Demographics: People Talking About This - F.65+',
#  '28 Days Demographics: People Talking About This - M.13-17',
#  '28 Days Demographics: People Talking About This - M.18-24',
#  '28 Days Demographics: People Talking About This - M.25-34',
#  '28 Days Demographics: People Talking About This - M.35-44',
#  '28 Days Demographics: People Talking About This - M.45-54',
#  '28 Days Demographics: People Talking About This - M.55-64',
#  '28 Days Demographics: People Talking About This - M.65+',
#  '28 Days Demographics: People Talking About This - U.25-34',
#  '28 Days Demographics: People Talking About This - U.35-44',
#  '28 Days Demographics: People Talking About This - U.45-54',
#  'Daily Country: People Talking About This - AR',
#  'Daily Country: People Talking About This - BO',
#  'Daily Country: People Talking About This - BR',
#  'Daily Country: People Talking About This - BZ',
#  'Daily Country: People Talking About This - CA',
#  'Daily Country: People Talking About This - CL',
#  'Daily Country: People Talking About This - CO',
#  'Daily Country: People Talking About This - CR',
#  'Daily Country: People Talking About This - DO',
#  'Daily Country: People Talking About This - EC',
#  'Daily Country: People Talking About This - GT',
#  'Daily Country: People Talking About This - HN',
#  'Daily Country: People Talking About This - IN',
#  'Daily Country: People Talking About This - JO',
#  'Daily Country: People Talking About This - MX',
#  'Daily Country: People Talking About This - MY',
#  'Daily Country: People Talking About This - MZ',
#  'Daily Country: People Talking About This - NI',
#  'Daily Country: People Talking About This - PA',
#  'Daily Country: People Talking About This - PE',
#  'Daily Country: People Talking About This - PH',
#  'Daily Country: People Talking About This - PR',
#  'Daily Country: People Talking About This - PY',
#  'Daily Country: People Talking About This - SV',
#  'Daily Country: People Talking About This - US',
#  'Daily Country: People Talking About This - UY',
#  'Daily Country: People Talking About This - VE',
#  'Weekly Country: People Talking About This - AR',
#  'Weekly Country: People Talking About This - BO',
#  'Weekly Country: People Talking About This - BR',
#  'Weekly Country: People Talking About This - BZ',
#  'Weekly Country: People Talking About This - CA',
#  'Weekly Country: People Talking About This - CL',
#  'Weekly Country: People Talking About This - CO',
#  'Weekly Country: People Talking About This - CR',
#  'Weekly Country: People Talking About This - DO',
#  'Weekly Country: People Talking About This - EC',
#  'Weekly Country: People Talking About This - GT',
#  'Weekly Country: People Talking About This - HN',
#  'Weekly Country: People Talking About This - IN',
#  'Weekly Country: People Talking About This - JO',
#  'Weekly Country: People Talking About This - MX',
#  'Weekly Country: People Talking About This - MY',
#  'Weekly Country: People Talking About This - MZ',
#  'Weekly Country: People Talking About This - NI',
#  'Weekly Country: People Talking About This - PA',
#  'Weekly Country: People Talking About This - PE',
#  'Weekly Country: People Talking About This - PH',
#  'Weekly Country: People Talking About This - PR',
#  'Weekly Country: People Talking About This - PY',
#  'Weekly Country: People Talking About This - SV',
#  'Weekly Country: People Talking About This - US',
#  'Weekly Country: People Talking About This - UY',
#  'Weekly Country: People Talking About This - VE',
#  '28 Days Country: People Talking About This - AR',
#  '28 Days Country: People Talking About This - BO',
#  '28 Days Country: People Talking About This - BR',
#  '28 Days Country: People Talking About This - BZ',
#  '28 Days Country: People Talking About This - CA',
#  '28 Days Country: People Talking About This - CL',
#  '28 Days Country: People Talking About This - CO',
#  '28 Days Country: People Talking About This - CR',
#  '28 Days Country: People Talking About This - CU',
#  '28 Days Country: People Talking About This - DO',
#  '28 Days Country: People Talking About This - EC',
#  '28 Days Country: People Talking About This - GT',
#  '28 Days Country: People Talking About This - HN',
#  '28 Days Country: People Talking About This - IN',
#  '28 Days Country: People Talking About This - JO',
#  '28 Days Country: People Talking About This - MX',
#  '28 Days Country: People Talking About This - MY',
#  '28 Days Country: People Talking About This - MZ',
#  '28 Days Country: People Talking About This - NI',
#  '28 Days Country: People Talking About This - PA',
#  '28 Days Country: People Talking About This - PE',
#  '28 Days Country: People Talking About This - PH',
#  '28 Days Country: People Talking About This - PR',
#  '28 Days Country: People Talking About This - PY',
#  '28 Days Country: People Talking About This - SV',
#  '28 Days Country: People Talking About This - US',
#  '28 Days Country: People Talking About This - UY',
#  '28 Days Country: People Talking About This - VE',
#  'Daily City: People Talking About This - Ébano, Mexico',
#  'Daily City: People Talking About This - Abancay, Peru',
#  'Daily City: People Talking About This - Acajutla, El Salvador',
#  'Daily City: People Talking About This - Acancéh, Mexico',
#  'Daily City: People Talking About This - Acaponeta, Mexico',
#  'Daily City: People Talking About This - Acapulco, Mexico',
#  'Daily City: People Talking About This - Acaxochitlán, Mexico',
#  'Daily City: People Talking About This - Acayucan, Mexico',
#  'Daily City: People Talking About This - Acolman, Mexico',
#  'Daily City: People Talking About This - Actopan, Mexico',
#  'Daily City: People Talking About This - Acuña, Mexico',
#  'Daily City: People Talking About This - Agua Dulce, Mexico',
#  'Daily City: People Talking About This - Aguadilla, Puerto Rico',
#  'Daily City: People Talking About This - Aguas Calientes, Venezuela',
#  'Daily City: People Talking About This - Aguascalientes, Mexico',
#  'Daily City: People Talking About This - Aguililla, Mexico',
#  'Daily City: People Talking About This - Ahuachapán, El Salvador',
#  'Daily City: People Talking About This - Alpoyeca, Mexico',
#  'Daily City: People Talking About This - Altamira, Mexico',
#  'Daily City: People Talking About This - Alto de la Alianza, Peru',
#  'Daily City: People Talking About This - Alvarado, Mexico',
#  'Daily City: People Talking About This - Amatepec, Mexico',
#  'Daily City: People Talking About This - Amatlán de Cañas, Mexico',
#  'Daily City: People Talking About This - Amayuca, Mexico',
#  'Daily City: People Talking About This - Amman, Jordan',
#  'Daily City: People Talking About This - Apan, Mexico',
#  'Daily City: People Talking About This - Apaseo el Alto, Mexico',
#  'Daily City: People Talking About This - Apaseo el Grande, Mexico',
#  'Daily City: People Talking About This - Apastepeque, El Salvador',
#  'Daily City: People Talking About This - Apizaco, Mexico',
#  'Daily City: People Talking About This - Apodaca, Mexico',
#  'Daily City: People Talking About This - Arequipa, Peru',
#  'Daily City: People Talking About This - Astacinga, Mexico',
#  'Daily City: People Talking About This - Asunción, Paraguay',
#  'Daily City: People Talking About This - Ataco, El Salvador',
#  'Daily City: People Talking About This - Atlixco, Mexico',
#  'Daily City: People Talking About This - Atotonilco Tula, Mexico',
#  'Daily City: People Talking About This - Atoyac de Alvarez, Mexico',
#  'Daily City: People Talking About This - Ayo el Grande, Mexico',
#  'Daily City: People Talking About This - Baca, Mexico',
#  'Daily City: People Talking About This - Balancan, Mexico',
#  'Daily City: People Talking About This - Banfield, Argentina',
#  'Daily City: People Talking About This - Bangalore, India',
#  'Daily City: People Talking About This - Barcelona, Venezuela',
#  'Daily City: People Talking About This - Barrancabermeja, Colombia',
#  'Daily City: People Talking About This - Barranquilla, Colombia',
#  'Daily City: People Talking About This - Bellavista, Peru',
#  'Daily City: People Talking About This - Belmopan, Belize',
#  'Daily City: People Talking About This - Bluefields, Nicaragua',
#  'Daily City: People Talking About This - Boca Barranca, Costa Rica',
#  'Daily City: People Talking About This - Boca Tulua, Colombia',
#  'Daily City: People Talking About This - Bogotá, Colombia',
#  'Daily City: People Talking About This - Buckeye, AZ',
#  'Daily City: People Talking About This - Buena Fe, Ecuador',
#  'Daily City: People Talking About This - Buenos Aires, Argentina',
#  'Daily City: People Talking About This - Cárdenas, Mexico',
#  'Daily City: People Talking About This - Cúcuta, Colombia',
#  'Daily City: People Talking About This - Cañete, Peru',
#  'Daily City: People Talking About This - Cañitas de Felipe Pescador, Mexico',
#  'Daily City: People Talking About This - Caacupé, Paraguay',
#  'Daily City: People Talking About This - Cabo San Lucas, Mexico',
#  'Daily City: People Talking About This - Cadereyta Jiménez, Mexico',
#  'Daily City: People Talking About This - Cajabamba, Peru',
#  'Daily City: People Talking About This - Cajamarca, Peru',
#  'Daily City: People Talking About This - Calceta, Ecuador',
#  'Daily City: People Talking About This - Callao, Peru',
#  'Daily City: People Talking About This - Calnalí, Mexico',
#  'Daily City: People Talking About This - Calumet City, IL',
#  'Daily City: People Talking About This - Cancún, Mexico',
#  'Daily City: People Talking About This - Caracas, Venezuela',
#  'Daily City: People Talking About This - Carhuaz, Peru',
#  'Daily City: People Talking About This - Carlos A. Carrillo, Mexico',
#  'Daily City: People Talking About This - Cartagena, Colombia',
#  'Daily City: People Talking About This - Catache, Peru',
#  'Daily City: People Talking About This - Cayma, Peru',
#  'Daily City: People Talking About This - Cebu City, Philippines',
#  'Daily City: People Talking About This - Cecilio Báez, Paraguay',
#  'Daily City: People Talking About This - Ceiba Amelia, Guatemala',
#  'Daily City: People Talking About This - Celaya, Mexico',
#  'Daily City: People Talking About This - Cerralvo, Mexico',
#  'Daily City: People Talking About This - Cerro Colorado, Peru',
#  'Daily City: People Talking About This - Chalco, Mexico',
#  'Daily City: People Talking About This - Champotón, Mexico',
#  'Daily City: People Talking About This - Chao, Peru',
#  'Daily City: People Talking About This - Chepén, Peru',
#  'Daily City: People Talking About This - Chetumal, Mexico',
#  'Daily City: People Talking About This - Chiapa de Corzo, Mexico',
#  'Daily City: People Talking About This - Chiclayo, Peru',
#  'Daily City: People Talking About This - Chicoloapan, Mexico',
#  'Daily City: People Talking About This - Chihuahua, Mexico',
#  'Daily City: People Talking About This - Chilapa de Alvarez, Mexico',
#  'Daily City: People Talking About This - Chilpancingo, Mexico',
#  'Daily City: People Talking About This - Chimalhuacán, Mexico',
#  'Daily City: People Talking About This - Chimbote, Peru',
#  'Daily City: People Talking About This - Chinandega, Nicaragua',
#  'Daily City: People Talking About This - Chincha Alta, Peru',
#  'Daily City: People Talking About This - Choloma, Honduras',
#  'Daily City: People Talking About This - Chulucanas, Peru',
#  'Daily City: People Talking About This - Ciénaga, Colombia',
#  'Daily City: People Talking About This - Ciénega de Flores, Mexico',
#  'Daily City: People Talking About This - Citlaltépec, Mexico',
#  'Daily City: People Talking About This - Ciudad Avila Camacho, Mexico',
#  'Daily City: People Talking About This - Ciudad Guzmán, Mexico',
#  'Daily City: People Talking About This - Ciudad Juárez, Mexico',
#  'Daily City: People Talking About This - Ciudad Madero, Mexico',
#  'Daily City: People Talking About This - Ciudad Miguel Alemán, Mexico',
#  'Daily City: People Talking About This - Ciudad Obregón, Mexico',
#  'Daily City: People Talking About This - Ciudad Satélite, Mexico',
#  'Daily City: People Talking About This - Ciudad Valles, Mexico',
#  'Daily City: People Talking About This - Ciudad Victoria, Mexico',
#  'Daily City: People Talking About This - Ciudad del Carmen, Mexico',
#  'Daily City: People Talking About This - Ciudad del Este, Paraguay',
#  'Daily City: People Talking About This - Coacalco, Mexico',
#  'Daily City: People Talking About This - Coatzacoalcos, Mexico',
#  'Daily City: People Talking About This - Cochabamba, Bolivia',
#  'Daily City: People Talking About This - Colón, El Salvador',
#  'Daily City: People Talking About This - Colima, Mexico',
#  'Daily City: People Talking About This - Colonia del Sacramento, Uruguay',
#  'Daily City: People Talking About This - Comalcalco, Mexico',
#  'Daily City: People Talking About This - Comitan, Mexico',
#  'Daily City: People Talking About This - Coquimbo, Chile',
#  'Daily City: People Talking About This - Coral Springs, FL',
#  'Daily City: People Talking About This - Corrales, Peru',
#  'Daily City: People Talking About This - Cosamaloapan de Carpio, Mexico',
#  'Daily City: People Talking About This - Coscomatepec, Mexico',
#  'Daily City: People Talking About This - Coyotepec, Mexico',
#  'Daily City: People Talking About This - Cuautitlán, Mexico',
#  'Daily City: People Talking About This - Cuautitlán Izcalli, Mexico',
#  'Daily City: People Talking About This - Cuencamé, Mexico',
#  'Daily City: People Talking About This - Cuernavaca, Mexico',
#  'Daily City: People Talking About This - Culasi, Philippines',
#  'Daily City: People Talking About This - Culiacán, Mexico',
#  'Daily City: People Talking About This - Culpón, Peru',
#  'Daily City: People Talking About This - Cuquío, Mexico',
#  'Daily City: People Talking About This - Curanipe, Chile',
#  'Daily City: People Talking About This - Cusco, Peru',
#  'Daily City: People Talking About This - Danlí, Honduras',
#  'Daily City: People Talking About This - Dasmariñas, Philippines',
#  'Daily City: People Talking About This - Davao City, Philippines',
#  'Daily City: People Talking About This - Desamparados, Costa Rica',
#  'Daily City: People Talking About This - Diriamba, Nicaragua',
#  'Daily City: People Talking About This - Durango, Mexico',
#  'Daily City: People Talking About This - Dzan, Mexico',
#  'Daily City: People Talking About This - Ecatepec de Morelos, Mexico',
#  'Daily City: People Talking About This - Ejido Plan de Ayala, Mexico',
#  'Daily City: People Talking About This - El Carmen, Ecuador',
#  'Daily City: People Talking About This - El Llano, Honduras',
#  'Daily City: People Talking About This - El Naranjo, Mexico',
#  'Daily City: People Talking About This - El Salto, Mexico',
#  'Daily City: People Talking About This - Eleodoro Castillo, Mexico',
#  'Daily City: People Talking About This - Ensenada, Mexico',
#  'Daily City: People Talking About This - Ensenada Blanca, Mexico',
#  'Daily City: People Talking About This - Escuinapa, Mexico',
#  'Daily City: People Talking About This - Esmeraldas, Ecuador',
#  'Daily City: People Talking About This - Estado de México, Mexico',
#  'Daily City: People Talking About This - Estelí, Nicaragua',
#  'Daily City: People Talking About This - Ferreñafe, Peru',
#  'Daily City: People Talking About This - Foz do Iguaçu, PR, Brazil',
#  'Daily City: People Talking About This - Frontera Comalapa, Mexico',
#  'Daily City: People Talking About This - Gómez Palacio, Mexico',
#  'Daily City: People Talking About This - Garcia, Mexico',
#  'Daily City: People Talking About This - General Escobedo, Mexico',
#  'Daily City: People Talking About This - General Rodríguez, Argentina',
#  'Daily City: People Talking About This - General Zuazua, Mexico',
#  'Daily City: People Talking About This - Granada, Nicaragua',
#  'Daily City: People Talking About This - Granby, QC, Canada',
#  'Daily City: People Talking About This - Gregorio de Laferrère, Argentina',
#  'Daily City: People Talking About This - Guadalajara, Mexico',
#  'Daily City: People Talking About This - Guadalupe, Mexico',
#  'Daily City: People Talking About This - Gualaceo, Ecuador',
#  'Daily City: People Talking About This - Guanajuato, Mexico',
#  'Daily City: People Talking About This - Guasave, Mexico',
#  'Daily City: People Talking About This - Guatemala City, Guatemala',
#  'Daily City: People Talking About This - Guayaquil, Ecuador',
#  'Daily City: People Talking About This - Hermosillo, Mexico',
#  'Daily City: People Talking About This - Heroica Matamoros, Mexico',
#  'Daily City: People Talking About This - Hidalgo, Mexico',
#  'Daily City: People Talking About This - Homún, Mexico',
#  'Daily City: People Talking About This - Houston, TX',
#  'Daily City: People Talking About This - Huánuco, Peru',
#  'Daily City: People Talking About This - Huacho, Peru',
#  ...]

# %%
df5=df5.iloc[:,:12]
df5['Date']= pd.to_datetime(df5['Date'])

# %%
df5.to_csv('FB_followers.csv',  index=False)

# %% [markdown]
# # Facebook - ads

# %%
df6 = pd.read_csv(r'%s\Reporte-ad-Noggin-May-24-2019-Jun-28-2019.csv' % carpeta, sep=',', skiprows=[1])

# %%
df6=df6.fillna(0)

# %%
df6['VTR'] = df6['3-Second Video Views'] / df6['Reach']

df6['E.R.'] =(df6['Post Reactions'] + df6['Post Comments'] + df6['Post Shares']+ df6['Link Clicks']) / df6['Reach']

# %%
df6.to_csv('ADS.csv',  index=False)

# %%
list(df6)
# Out:
# ['Campaign Name',
#  'Ad Set Name',
#  'Platform',
#  'Delivery Status',
#  'Delivery Level',
#  'Campaign Name.1',
#  'Result Type',
#  'Results',
#  'Reach',
#  'Impressions',
#  'Cost per Result',
#  'Amount Spent (ARS)',
#  '3-Second Video Views',
#  'Video Average Watch Time',
#  'Frequency',
#  'Starts',
#  'Ends',
#  'Link Clicks',
#  'CPC (Cost per Link Click)',
#  'CTR (Link Click-Through Rate)',
#  'Post Reactions',
#  'Post Comments',
#  'Post Shares',
#  '10-Second Video Views',
#  'Cost per 10-Second Video View',
#  'Reporting Starts',
#  'Reporting Ends',
#  'VTR',
#  'E.R.']

# %% [markdown]
# ## ADS + organic

# %%
df7 = pd.DataFrame()

df7['Reactions'] = df6['Post Reactions'] + (df['Lifetime Talking About This (Post) by action type - like'][df['Lifetime Post Paid Reach'] == 0])

df7['Comments'] = df6['Post Comments'] + (df['Lifetime Talking About This (Post) by action type - comment'][df['Lifetime Post Paid Reach'] == 0])

df7['Shares'] = df6['Post Shares'] + (df['Lifetime Talking About This (Post) by action type - share'][df['Lifetime Post Paid Reach'] == 0])

df7.to_csv('Final.csv', sep=',')

# %%
list(df)
# Out:
# ['Post ID',
#  'Permalink',
#  'Type',
#  'Countries',
#  'Languages',
#  'Posted',
#  'Audience Targeting',
#  'Lifetime Post Total Reach',
#  'Lifetime Post organic reach',
#  'Lifetime Post Paid Reach',
#  'Lifetime Post Total Impressions',
#  'Lifetime Post Organic Impressions',
#  'Lifetime Post Paid Impressions',
#  'Lifetime Engaged Users',
#  'Lifetime Matched Audience Targeting Consumers on Post',
#  'Lifetime Matched Audience Targeting Consumptions on Post',
#  'Lifetime Negative Feedback from Users',
#  'Lifetime Negative Feedback',
#  'Lifetime Post Impressions by people who have liked your Page',
#  'Lifetime Post reach by people who like your Page',
#  'Lifetime Post Paid Impressions by people who have liked your Page',
#  'Lifetime Paid reach of a post by people who like your Page',
#  'Lifetime People who have liked your Page and engaged with your post',
#  'Lifetime Organic views to 95%',
#  'Lifetime Organic views to 95%.1',
#  'Lifetime Paid views to 95%',
#  'Lifetime Paid views to 95%.1',
#  'Lifetime Organic Video Views',
#  'Lifetime Organic Video Views.1',
#  'Lifetime Paid Video Views',
#  'Lifetime Paid Video Views.1',
#  'Lifetime Average time video viewed',
#  'Lifetime Video length',
#  'Lifetime Talking About This (Post) by action type - like',
#  'Lifetime Talking About This (Post) by action type - comment',
#  'Lifetime Talking About This (Post) by action type - share',
#  'Lifetime Post Stories by action type - like',
#  'Lifetime Post Stories by action type - comment',
#  'Lifetime Post Stories by action type - share',
#  'Lifetime Post Audience Targeting Unique Consumptions by Type - video play',
#  'Lifetime Post Audience Targeting Unique Consumptions by Type - other clicks',
#  'Lifetime Post Audience Targeting Unique Consumptions by Type - photo view',
#  'Lifetime Post Audience Targeting Unique Consumptions by Type - link clicks',
#  'Lifetime Matched Audience Targeting Consumptions by Type - video play',
#  'Lifetime Matched Audience Targeting Consumptions by Type - other clicks',
#  'Lifetime Matched Audience Targeting Consumptions by Type - photo view',
#  'Lifetime Matched Audience Targeting Consumptions by Type - link clicks',
#  'Lifetime Negative Feedback from Users by Type - hide_all_clicks',
#  'Lifetime Negative Feedback by Type - hide_all_clicks',
#  'Fecha',
#  'Hora',
#  'Dia',
#  'Mes',
#  'VTR',
#  'E.R.']

# %% [markdown]
# # Instagram - Posts

# %%
df2= pd.read_excel(open('rolling-export-nogginbrasil-936364-1125410-20190501-20190531-1561574718.xlsx', 'rb'),
...               sheet_name='My media', skiprows=[0])

# %%
df2=df2.drop(['Caption'], axis=1)

# %%
new2 = df2['Date and time'].str.split(" ", n = 1, expand = True) 
df2['Fecha'] = new2[0]
df2['Hora'] = new2[1]
df2['Dia'] = pd.DatetimeIndex(df2['Fecha']).dayofweek
dayDict = {6:'Domingo', 0:'Lunes', 1:'Martes', 2:'Miércoles', 3:'Jueves', 4: 'Viernes', 5:'Sábado' }
df2['Dia']=df2['Dia'].map(dayDict)

df2['Fecha']= pd.to_datetime(df2['Fecha']) 
df2['Mes'] = df2.Fecha.dt.month
df2['Hora']= pd.to_datetime(df2['Hora']) 
df2['Hora'] =  df2.Hora.dt.hour


df2=df2.fillna(0)

# %%
df2.to_csv('IG_post.csv', index=False)

# %% [markdown]
# # Instagram - Stories

# %%
df3= pd.read_excel(open('rolling-export-nogginbrasil-936364-1125410-20190501-20190531-1561574718.xlsx', 'rb'),
...               sheet_name='My stories', skiprows=[0])

# %%
new3 = df3['Date and time'].str.split(" ", n = 1, expand = True) 
df3['Fecha'] = new3[0]
df3['Hora'] = new3[1]
df3['Dia'] = pd.DatetimeIndex(df3['Fecha']).dayofweek
dayDict = {6:'Domingo', 0:'Lunes', 1:'Martes', 2:'Miércoles', 3:'Jueves', 4: 'Viernes', 5:'Sábado' }
df3['Dia']=df3['Dia'].map(dayDict)

df3['Fecha']= pd.to_datetime(df3['Fecha']) 
df3['Mes'] = df3.Fecha.dt.month
df3['Hora']= pd.to_datetime(df3['Hora']) 
df3['Hora'] =  df3.Hora.dt.hour


df3=df3.fillna(0)

# %%
df3.to_csv('IgStories.csv', index=False)

# %% [markdown]
# # Instagram - Likes

# %%
df4= pd.read_excel(open('rolling-export-nogginbrasil-936364-1125410-20190501-20190531-1561574718.xlsx', 'rb'),
...               sheet_name='Followers Growth', skiprows=0)

# %%
df4=df4.iloc[:,:4]
df4['Day']= pd.to_datetime(df4['Day'])

# %%
df4.head()
# Out:
#          Day  Followers  Evolution  Media posted
# 0 2019-05-01       3040     0.0003             0
# 1 2019-05-02       3034    -0.0020             0
# 2 2019-05-03       3034     0.0000             0
# 3 2019-05-04       3034     0.0000             0
# 4 2019-05-05       3030    -0.0013             0

# %%
df4.to_csv('IGLikes.csv', index=False)
